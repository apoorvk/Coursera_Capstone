# %% [markdown]
# # Battle of Neighbourhoods - New York

# %% [markdown]
# ## Objective
# Objective of the final assignment of IBM Capstone Project were to define a real-life business problem, scrap data from the web and use Foursquare location data to compare different neighbourhood in New York to find out which neighbourhood is suitable for starting a restaurant business. In this report I will go through the Background and Business problem, data preparation and analysis section step by step.

# %% [markdown]
# ![NY.jpg](attachment:NY.jpg)

# %% [markdown]
# ## Discussion on Business Problem / Background

# %% [markdown]
# **Background:**
# The city of New York is one of the world’s most populous megacities. It is most diversified as a lot of people from different countries live and work there. Being the most populous city in United states it provided with many business opportunities but it’s also very competitive. New York city has been described as the cultural, financial and media capital of the world. The analysis from this report will the new business strategically target the market.
#
# **Problem:**
# The problem we are trying to solve here is to find a place in New York to open a new restaurant. Opening any type of business, you need to consider so many things for example Location, Niche, population around the location chosen and so on.  There are few questions that we need answers for before moving forward.
# a)	What type of restaurant is going to be? Is it going to be fine dining restaurant or casual style dinner?
# b)	What kind of food we are serving is it going to be specific cuisine that will be serving like French, Italian, Indian or Continental.
# c)	Are we going to serving throughout the day or just a particular time in the day?
# d)	What are we looking for in terms of location – place with lot of parking space or lot of foot traffic?
#
# In this analysis we will focus on type of restaurants which are opened in and around the area and then decide if it’s a good place to open a new restaurant based on the popularity of cuisine around that place and the competition.

# %% [markdown]
# ## Target Audience
# Targeted audience for this project will be people looking to open a new restaurant business in New York.

# %% [markdown]
# ## Data

# %% [markdown]
# The dataset that I am going to use exist for free on the web. The link to the dataset is https://geo.nyu.edu/catalog/nyu_2451_34572 . The Neighbourhood has total of 5 Boroughs and 306 neighbourhoods. To understand it better, I am going to segment the neighbourhoods and explore them. In order to segmentation I will be getting the latitude and longitude of each neighbourhood and cluster them . The will the Foresquare location data to fetch the location of the restaurants in those neighbourhoods and then will a make decision by examining each cluster
